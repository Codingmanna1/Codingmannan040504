# %%
import pandas as pd
import numpy as np
import seaborn as sns

df = pd.read_csv("OSHack_BankCustomers.csv")

sns.barplot(x="loan", y="balance", data=df,  estimator=lambda x: len(x) / len(df) * 100)
# Out:
# <AxesSubplot:xlabel='loan', ylabel='balance'>

# %%
#sns.barplot(x="job", y="duration", data=df,  estimator=lambda x: len(x) / len(df) * 100, aspect = 2)
sns.set(rc={'figure.figsize':(14,8.7)})
sns.countplot(x="job",hue = "loan", data=df)
# Out:
# <AxesSubplot:xlabel='job', ylabel='count'>
